# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaSerrato/Intro-Programacion/blob/main/notebooks/00_introduccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción

# %% [markdown]
# ¡Bienvenido/a a este capítulo!
#
# Puedes ejecutarlo completo en Google Colab sin instalar nada.
#
# En este capítulo aprenderás el tema principal paso a paso y con ejemplos simples.
#
# Piensa en esto como aprender a conducir: al principio todo parece nuevo, pero con práctica las decisiones se vuelven automáticas.
#
# No necesitas entender todo de inmediato; lo importante es avanzar con calma y practicar.

# %% [markdown]
# En este capítulo conocerás el propósito del curso y cómo abordaremos el aprendizaje.
# Verás qué significa programar y cómo convertir ideas en pasos simples.
# Aprenderás a ejecutar tu primer código en Python.
# Este es el punto de partida para todo el recorrido del curso.

# %% [markdown]
# ## ¿Qué es `print()`?
#
# `print()` es una función de Python que muestra información en pantalla.
# Es como decirle al computador: "muéstrame esto".
# La usaremos constantemente para ver resultados mientras aprendemos.

# %% [markdown]
# ## Ejemplo guiado

# %%
print("Bienvenido al curso de Introducción a la Programación")
resultado = 7 + 5
print("7 + 5 =", resultado)

# %% [markdown]
# ## Ejercicios
#
# 1. Escribe un mensaje de bienvenida con tu nombre.

# %% [markdown]
# 2. Muestra el resultado de 12 * 3.

# %% [markdown]
# 3. Guarda tu edad en una variable y muéstrala.

# %% [markdown]
# 4. Guarda tu ciudad en una variable y muéstrala.

# %% [markdown]
# 5. Crea dos variables y muestra su suma.

# %% [markdown]
# 6. Crea una variable booleana y muéstrala.

# %% [markdown]
# 7. Escribe un mensaje que combine dos variables de texto.

# %% [markdown]
# 8. Mini-desafío: imprime un mensaje con tu nombre y tu edad en una sola línea.

# %% [markdown]
# 9. Mini–actividad: secuencia de pasos. Describe en 4–6 pasos cómo realizar una acción cotidiana (por ejemplo, preparar té o caminar al supermercado).

# %% [markdown]
# 10. Práctica adicional: crea tres variables (nombre, edad, ciudad) y muestra una frase completa con ellas.

# %% [markdown]
# 11. Práctica adicional: calcula el doble de un número guardado en una variable.

# %% [markdown]
# 12. Práctica adicional: muestra un mensaje usando una variable booleana.

# %% [markdown]
# ## Preguntas de comprensión
#
# - ¿Qué es programar en tus propias palabras?

# %% [markdown]
# - ¿Por qué es útil dividir un problema en pasos?

# %% [markdown]
# - ¿Qué hace la función print en Python?

# %% [markdown]
# - ¿Qué diferencia hay entre un valor y una variable?

# %% [markdown]
# <details>
# <summary><strong>Ver soluciones</strong></summary>
#
# ```python
# # solución del ejercicio 1
# print("Hola, soy Ana")
#
# # solución del ejercicio 2
# print(12 * 3)
#
# # solución del ejercicio 3
# edad = 20
# print(edad)
#
# # solución del ejercicio 4
# ciudad = "Bogotá"
# print(ciudad)
#
# # solución del ejercicio 5
# a = 4
# b = 6
# print(a + b)
#
# # solución del ejercicio 6
# activo = True
# print(activo)
#
# # solución del ejercicio 7
# nombre = "Ana"
# apellido = "Lopez"
# print(nombre + " " + apellido)
#
# # solución del ejercicio 8
# nombre = "Ana"
# edad = 20
# print(f"{nombre} tiene {edad} años")
#
# # solución del ejercicio 9
# pasos = ["Paso 1", "Paso 2", "Paso 3", "Paso 4"]
# print(pasos)
#
# # solución del ejercicio 10
# nombre = "Ana"
# edad = 20
# ciudad = "Bogotá"
# print(f"{nombre} tiene {edad} años y vive en {ciudad}")
#
# # solución del ejercicio 11
# numero = 7
# print(numero * 2)
#
# # solución del ejercicio 12
# activo = False
# print("Estado activo" if activo else "Estado inactivo")
#
# ```
# </details>

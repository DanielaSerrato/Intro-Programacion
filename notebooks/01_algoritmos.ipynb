# %% [markdown]
# # Algoritmos

# %% [markdown]
# **Bienvenida**
# ¡Bienvenido/a a este capítulo! Puedes ejecutarlo completo en Google Colab sin instalar nada.
# En este capítulo aprenderás el tema principal paso a paso y con ejemplos simples.
# Piensa en esto como aprender a conducir: al principio todo parece nuevo, pero con práctica las decisiones se vuelven automáticas.
# No necesitas entender todo de inmediato; lo importante es avanzar con calma y practicar.

# %% [markdown]
# En este capítulo aprenderás qué es un **algoritmo** y cómo describirlo con pasos claros.
# Antes de programar, es útil ordenar una idea en instrucciones simples.
# Eso evita errores y hace que el código sea más fácil de escribir.

# %% [markdown]
# ## ¿Qué es un algoritmo?
#
# Un algoritmo es una **secuencia ordenada de pasos** para resolver un problema.
# No necesita código: puede ser una lista de instrucciones escrita con palabras simples.

# %% [markdown]
# ## Ejemplo guiado
#
# **Problema:** saludar a una persona con su nombre.
#
# **Pasos del algoritmo:**
# 1. Pedir el nombre.
# 2. Guardar el nombre.
# 3. Mostrar un saludo con el nombre.

# %%
# Una forma simple de representar pasos usando variables
paso1 = "Pedir el nombre"
paso2 = "Guardar el nombre"
paso3 = "Mostrar el saludo"

print(paso1)
print(paso2)
print(paso3)

# %% [markdown]
# ## Ejercicios
#
# Sigue el formato en cada ejercicio: completa el bloque **TU CÓDIGO AQUÍ** y revisa el ejemplo.

# %% [markdown]
# ### Ejercicio 1: Algoritmo para preparar un sándwich
# **Enunciado:** escribe 3 pasos para preparar un sándwich y muéstralos en orden.
#
# **Ejemplo esperado:**
# ```
# 1. Tomar pan
# 2. Agregar relleno
# 3. Cerrar el sándwich
# ```
#
# **Pista:** puedes usar variables `paso1`, `paso2`, `paso3` y luego hacer `print`.

# %%
# TU CÓDIGO AQUÍ
paso1 = ""
paso2 = ""
paso3 = ""

print(f"1. {paso1}")
print(f"2. {paso2}")
print(f"3. {paso3}")

# Prueba simple
assert all(isinstance(paso, str) and paso for paso in [paso1, paso2, paso3])

# %% [markdown]
# ### Ejercicio 2: Algoritmo para lavarse las manos
# **Enunciado:** crea una variable `algoritmo` con un texto que tenga 4 pasos numerados, uno por línea.
#
# **Ejemplo esperado:**
# ```
# 1. Mojar las manos
# 2. Aplicar jabón
# 3. Frotar 20 segundos
# 4. Enjuagar
# ```
#
# **Pista:** usa `
# ` para saltos de línea dentro del texto.

# %%
# TU CÓDIGO AQUÍ
algoritmo = ""

print(algoritmo)

# Prueba simple
assert isinstance(algoritmo, str) and "
" in algoritmo

# %% [markdown]
# ### Ejercicio 3: Algoritmo para sumar dos números
# **Enunciado:** escribe los pasos en texto para sumar dos números. Usa una variable `pasos` con al menos 3 pasos separados por saltos de línea.
#
# **Ejemplo esperado:**
# ```
# 1. Leer el primer número
# 2. Leer el segundo número
# 3. Sumar y mostrar el resultado
# ```
#
# **Pista:** no necesitas programar la suma, solo describirla.

# %%
# TU CÓDIGO AQUÍ
pasos = ""

print(pasos)

# Prueba simple
assert isinstance(pasos, str) and "1." in pasos

# %% [markdown]
# ## Preguntas de comprensión
#
# Responde en una **celda Markdown** debajo de esta sección.
#
# - ¿Por qué es útil escribir los pasos antes de programar?
# - ¿Qué hace que un algoritmo sea claro?
# - ¿En qué se parece un algoritmo a una receta de cocina?

# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaSerrato/Intro-Programacion/blob/main/notebooks/02_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 2: Ejercicios

# %% [markdown]
# ## Ejercicio 1: Identificar capas
# Para cada elemento indica a qué capa pertenece (Presentación, Lógica o Datos):
#
# - Botón **“Reservar”**
# - Regla **“No permitir reservas superpuestas”**
# - Tabla **Reservas**

# %% [markdown]
# ## Ejercicio 2: Mapa de arquitectura
# Dibuja (en papel o en una herramienta) el flujo entre capas de un **sistema de ventas**.
# Incluye al menos 3 elementos por capa.

# %% [markdown]
# ## Ejercicio 3: Tablas y relaciones
# Define dos tablas relacionadas para un sistema de **cursos**:
#
# - Tabla **Estudiantes**
# - Tabla **Inscripciones**
#
# Indica PK y FK.

# %%
# Completa las tablas con al menos 2 registros cada una.

estudiantes = [
    # {"estudiante_id": 1, "nombre": "..."},
]

inscripciones = [
    # {"inscripcion_id": 100, "estudiante_id": 1, "curso": "..."},
]

# TODO: imprimir las inscripciones mostrando el nombre del estudiante.

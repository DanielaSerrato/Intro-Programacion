# %% [markdown]
# # Condicionales

# %% [markdown]
# **Bienvenida**
# ¡Bienvenido/a a este capítulo! Puedes ejecutarlo completo en Google Colab sin instalar nada.
# En este capítulo aprenderás el tema principal paso a paso y con ejemplos simples.
# Piensa en esto como aprender a conducir: al principio todo parece nuevo, pero con práctica las decisiones se vuelven automáticas.
# No necesitas entender todo de inmediato; lo importante es avanzar con calma y practicar.

# %% [markdown]
# Este capítulo introduce las decisiones en los programas mediante condicionales.
# Aprenderás a usar if, elif y else para controlar el flujo.
# Practicarás comparaciones y condiciones compuestas.
# Estas ideas serán clave para ejercicios y proyectos más complejos.

# %% [markdown]
# ## ¿Qué es un condicional?
#
# Un condicional permite que el programa tome decisiones.
# Evalúa una condición y elige qué camino seguir (if, elif, else).
# Es como decir: si pasa esto, haz aquello; si no, haz otra cosa.

# %% [markdown]
# ## Ejemplo guiado

# %%
edad = 18
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")

# %% [markdown]
# ## Ejercicios
#
# 1. Escribe un programa que diga si un número es positivo.
# 2. Escribe un programa que diga si un número es par.
# 3. Pide una edad y muestra si es mayor o menor de 18.
# 4. Compara dos números y muestra el mayor.
# 5. Pide una nota y muestra si aprobó (>= 60).
# 6. Usa condiciones compuestas con `and` y `or` para validar si una persona puede entrar (edad >= 18 y tiene invitación, o es acompañante).
# 7. Crea una condición compuesta con dos comparaciones.
# 8. Clasifica una temperatura en frío/templado/caliente.
# 9. Mini-desafío: determina si un número es múltiplo de 3 y 5.
# 10. Práctica adicional: evalúa si un número está entre 10 y 20 (inclusive).
# 11. Práctica adicional: determina si un año es bisiesto (divisible por 4 y no por 100, o por 400).
# 12. Práctica adicional: valida si un usuario tiene acceso con dos condiciones booleanas.

# %% [markdown]
# ## Preguntas de comprensión
#
# - ¿Para qué sirve un condicional?
# - ¿Cuál es la diferencia entre if y elif?
# - ¿Qué ocurre si ninguna condición se cumple?
# - ¿Cuándo usarías condiciones compuestas?
# - ¿Qué diferencia hay entre usar ‘and’ y ‘or’ en una condición compuesta?

# %% [markdown]
# <details>
# <summary><strong>Ver soluciones</strong></summary>
#
# ```python
# # solución del ejercicio 1
# n = 5\nprint(\"Positivo\" if n > 0 else \"No positivo\")
#
# # solución del ejercicio 2
# n = 4\nprint(\"Par\" if n % 2 == 0 else \"Impar\")
#
# # solución del ejercicio 3
# edad = 20\nprint(\"Mayor\" if edad >= 18 else \"Menor\")
#
# # solución del ejercicio 4
# a, b = 3, 7\nprint(a if a > b else b)
#
# # solución del ejercicio 5
# nota = 70\nprint(\"Aprobó\" if nota >= 60 else \"No aprobó\")
#
# # solución del ejercicio 6
# edad = 17\ninvitacion = True\nacompanante = False\nprint((edad >= 18 and invitacion) or acompanante)
#
# # solución del ejercicio 7
# a, b = 5, 10\nprint(a < b and b > 0)
#
# # solución del ejercicio 8
# t = 22\nprint(\"Frío\" if t < 15 else \"Templado\" if t <= 25 else \"Caliente\")
#
# # solución del ejercicio 9
# n = 15\nprint(n % 3 == 0 and n % 5 == 0)
#
# # solución del ejercicio 10
# n = 15\nprint(10 <= n <= 20)
#
# # solución del ejercicio 11
# anio = 2024\nprint((anio % 4 == 0 and anio % 100 != 0) or (anio % 400 == 0))
#
# # solución del ejercicio 12
# es_admin = True\nesta_activo = False\nprint(es_admin and esta_activo)
#
# ```
# </details>

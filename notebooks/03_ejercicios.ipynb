# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaSerrato/Intro-Programacion/blob/main/notebooks/03_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 3: Ejercicios

# %% [markdown]
# ## Ejercicio 1: Entidades y atributos
# Define entidades y atributos para un **sistema de biblioteca**.
# Incluye al menos 3 entidades y 3 atributos por entidad.

# %% [markdown]
# ## Ejercicio 2: Relaciones y cardinalidades
# Indica las relaciones y cardinalidades para:
#
# - Estudiante **toma** Curso
# - Profesor **imparte** Curso
# - Curso **incluye** Evaluación

# %% [markdown]
# ## Ejercicio 3: Diccionario de datos
# Completa el diccionario para una entidad **Paciente**.

# %%
diccionario_paciente = [
    {"atributo": "paciente_id", "tipo": "entero", "descripcion": ""},
    {"atributo": "nombre", "tipo": "texto", "descripcion": ""},
    {"atributo": "fecha_nacimiento", "tipo": "fecha", "descripcion": ""},
]

# TODO: completa las descripciones con frases claras.

# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaSerrato/Intro-Programacion/blob/main/notebooks/04_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 4: Ejercicios

# %% [markdown]
# ## Ejercicio 1: Transformación a tablas
# Convierte el siguiente modelo conceptual a tablas:
#
# **Entidades:** Proveedor, Producto, Compra.
# **Relación:** Proveedor realiza Compra y Compra incluye Producto.

# %% [markdown]
# ## Ejercicio 2: Claves PK y FK
# Define PK y FK para un sistema de **eventos**:
#
# - Evento
# - Asistente
# - Registro

# %%
# Completa las definiciones lógicas (tabla, columnas, PK/FK)

modelo_logico = {
    "Evento": {"pk": "", "columnas": []},
    "Asistente": {"pk": "", "columnas": []},
    "Registro": {"pk": "", "fks": [], "columnas": []},
}

# TODO: agrega columnas y define claves.

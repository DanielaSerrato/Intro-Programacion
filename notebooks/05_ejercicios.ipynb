# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaSerrato/Intro-Programacion/blob/main/notebooks/05_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 5: Ejercicios

# %% [markdown]
# ## Ejercicio 1: Crear DDL
# Escribe el DDL para un sistema de **inventario** con tablas:
#
# - Productos
# - Categorias
# - Movimientos

# %% [markdown]
# ## Ejercicio 2: Elegir tipos de datos
# Define los tipos para estos campos:
#
# - `fecha_ingreso`
# - `precio_unitario`
# - `estado` (activo/inactivo)

# %% [markdown]
# ## Ejercicio 3: Constraints
# Agrega `PK`, `FK`, `NOT NULL` y `UNIQUE` donde sea necesario.

# %%
# Escribe tu SQL debajo
sql_ddl = """
-- CREATE TABLE ...
"""

print(sql_ddl)

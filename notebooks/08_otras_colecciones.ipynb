# %% [markdown]
# # Otras colecciones en Python: Tuplas y Conjuntos (sets)

# %% [markdown]
# **Bienvenida**
# ¡Bienvenido/a a este capítulo! Puedes ejecutarlo completo en Google Colab sin instalar nada.
# En este capítulo aprenderás el tema principal paso a paso y con ejemplos simples.
# Piensa en esto como aprender a conducir: al principio todo parece nuevo, pero con práctica las decisiones se vuelven automáticas.
# No necesitas entender todo de inmediato; lo importante es avanzar con calma y practicar.

# %% [markdown]
# En este capítulo conocerás dos colecciones adicionales: **tuplas** y **sets**.
# Verás cuándo conviene usar cada una y cómo crear ejemplos sencillos.

# %% [markdown]
# ## ¿Qué son las tuplas y los sets?
#
# - **Tupla:** colección ordenada e inmutable.
# - **Set (conjunto):** colección no ordenada y sin elementos repetidos.

# %% [markdown]
# ## Ejemplo guiado

# %%
# Tupla
coordenadas = (10, 20)
print(coordenadas[0])

# Set
colores = {"rojo", "azul", "rojo"}
print(colores)

# %% [markdown]
# ## Ejercicios
#
# Sigue el formato en cada ejercicio: completa el bloque **TU CÓDIGO AQUÍ** y revisa el ejemplo.

# %% [markdown]
# ### Ejercicio 1: Crear una tupla
# **Enunciado:** crea una tupla `datos` con tu nombre, edad y ciudad.
#
# **Ejemplo esperado:**
# ```
# ('Ana', 20, 'Cali')
# ```
#
# **Pista:** usa paréntesis `()`.

# %%
# TU CÓDIGO AQUÍ
datos = ()

print(datos)

# Prueba simple
assert isinstance(datos, tuple) and len(datos) == 3

# %% [markdown]
# ### Ejercicio 2: Acceder a una tupla
# **Enunciado:** muestra el segundo elemento de la tupla `datos`.
#
# **Ejemplo esperado:**
# ```
# 20
# ```
#
# **Pista:** el índice 1 corresponde al segundo elemento.

# %%
# TU CÓDIGO AQUÍ
datos = ("Ana", 20, "Cali")

segundo = datos[1]
print(segundo)

# Prueba simple
assert segundo == 20

# %% [markdown]
# ### Ejercicio 3: Eliminar duplicados con set
# **Enunciado:** crea un set `numeros` a partir de una lista con números repetidos y muestra el resultado.
#
# **Ejemplo esperado:**
# ```
# {1, 2, 3}
# ```
#
# **Pista:** puedes usar `set(lista)`.

# %%
# TU CÓDIGO AQUÍ
lista = [1, 2, 2, 3, 3]

numeros = set(lista)
print(numeros)

# Prueba simple
assert len(numeros) == 3

# %% [markdown]
# ## Preguntas de comprensión
#
# Responde en una **celda Markdown** debajo de esta sección.
#
# - ¿Cuándo usarías una tupla en lugar de una lista?
# - ¿Qué ventaja tiene un set?

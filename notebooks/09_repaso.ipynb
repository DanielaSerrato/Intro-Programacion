# %% [markdown]
# # Repaso general del curso

# %% [markdown]
# **Bienvenida**
# ¡Bienvenido/a a este capítulo! Puedes ejecutarlo completo en Google Colab sin instalar nada.
# En este capítulo aprenderás el tema principal paso a paso y con ejemplos simples.
# Piensa en esto como aprender a conducir: al principio todo parece nuevo, pero con práctica las decisiones se vuelven automáticas.
# No necesitas entender todo de inmediato; lo importante es avanzar con calma y practicar.

# %% [markdown]
# Este capítulo integra los conceptos vistos hasta ahora.
# Practicarás algoritmos, variables, condicionales, loops y funciones.
# El objetivo es reforzar fluidez antes del proyecto final.
# Aquí consolidarás tu base para resolver problemas completos.

# %% [markdown]
# ## Ejemplo guiado

# %%
numeros = [1, 2, 3, 4, 5]\npares = [n for n in numeros if n % 2 == 0]\nprint(pares)\n

# %% [markdown]
# ## Ejercicios
#
# 1. Crea una función que sume una lista.
# 2. Crea una función que salude con un nombre.
# 3. Cuenta cuántas vocales tiene un texto.
# 4. Filtra los números pares de una lista.
# 5. Crea un diccionario con nombre y edad.
# 6. Usa un loop para calcular el promedio de una lista.
# 7. Combina condicionales y loops para contar mayores de 18.
# 8. Mini-desafío: procesa una lista y devuelve solo los valores únicos.
# 9. Ejercicio integrador: crea una lista de estudiantes (diccionarios) y una función que filtre los mayores de 18.
# 10. Práctica adicional: crea una función que convierta una lista de notas en un diccionario con índice como clave.
# 11. Práctica adicional: usa una función para sumar los precios de un carrito (lista de diccionarios).
# 12. Práctica adicional: combina listas y diccionarios para contar ocurrencias de palabras.

# %% [markdown]
# ## Preguntas de comprensión
#
# - ¿Qué conceptos se combinan en un programa completo?
# - ¿Por qué es útil repasar antes del proyecto final?
# - ¿Qué tema te resulta más difícil y por qué?

# %% [markdown]
# <details>
# <summary><strong>Ver soluciones</strong></summary>
#
# ```python
# # solución del ejercicio 1
# def sumar_lista(lista):\n    return sum(lista)\nprint(sumar_lista([1, 2, 3]))
#
# # solución del ejercicio 2
# def saludar(nombre):\n    return f\"Hola {nombre}\"\nprint(saludar(\"Ana\"))
#
# # solución del ejercicio 3
# def contar_vocales(texto):\n    vocales = \"aeiouáéíóúAEIOUÁÉÍÓÚ\"\n    return sum(1 for c in texto if c in vocales)\nprint(contar_vocales(\"Hola\"))
#
# # solución del ejercicio 4
# nums = [1, 2, 3, 4]\nprint([n for n in nums if n % 2 == 0])
#
# # solución del ejercicio 5
# persona = {\"nombre\": \"Ana\", \"edad\": 20}\nprint(persona)
#
# # solución del ejercicio 6
# nums = [1, 2, 3, 4]\nprom = sum(nums) / len(nums)\nprint(prom)
#
# # solución del ejercicio 7
# edades = [15, 20, 25]\nmayores = [e for e in edades if e >= 18]\nprint(len(mayores))
#
# # solución del ejercicio 8
# nums = [1, 1, 2, 3, 3]\nprint(list(set(nums)))
#
# # solución del ejercicio 9
# estudiantes = [{\"nombre\": \"Ana\", \"edad\": 17}, {\"nombre\": \"Luis\", \"edad\": 20}]\n\ndef filtrar_mayores(lista):\n    return [e for e in lista if e[\"edad\"] >= 18]\n\nprint(filtrar_mayores(estudiantes))
#
# # solución del ejercicio 10
# notas = [3.5, 4.0, 4.2]\nprint({i: n for i, n in enumerate(notas)})
#
# # solución del ejercicio 11
# carrito = [{\"precio\": 10}, {\"precio\": 5}]\nprint(sum(item[\"precio\"] for item in carrito))
#
# # solución del ejercicio 12
# palabras = [\"hola\", \"hola\", \"curso\"]\nconteo = {}\nfor p in palabras:\n    conteo[p] = conteo.get(p, 0) + 1\nprint(conteo)
#
# ```
# </details>

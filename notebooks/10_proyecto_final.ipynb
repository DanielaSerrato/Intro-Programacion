# %% [markdown]
# # Proyecto Final: Sistema de Gestión de Usuarios
#
# En este proyecto crearás una mini-aplicación que permita:
# - Registrar usuarios
# - Mostrar usuarios
# - Buscar por nombre
# - Eliminar usuarios
# - Organizar el código en funciones
#
# Este proyecto integra todo lo aprendido en el curso.

# %% [markdown]
# **Bienvenida**
# ¡Bienvenido/a a este capítulo! Puedes ejecutarlo completo en Google Colab sin instalar nada.
# En este capítulo aprenderás el tema principal paso a paso y con ejemplos simples.
# Piensa en esto como aprender a conducir: al principio todo parece nuevo, pero con práctica las decisiones se vuelven automáticas.
# No necesitas entender todo de inmediato; lo importante es avanzar con calma y practicar.

# %% [markdown]
# ## Datos iniciales
#
# Usaremos una lista de diccionarios para guardar usuarios.

# %%
# Lista principal de usuarios
usuarios = []

# %% [markdown]
# ## Paso 1: Registrar usuarios
#
# Crea una función `registrar_usuario` que reciba `nombre`, `edad` y `ciudad`,
# cree un diccionario y lo agregue a la lista `usuarios`.

# %%
# TU CÓDIGO AQUÍ

def registrar_usuario(nombre, edad, ciudad):
    usuario = {"nombre": nombre, "edad": edad, "ciudad": ciudad}
    usuarios.append(usuario)
    return usuario

# Pruebas simples
usuarios.clear()
registrar_usuario("Ana", 20, "Lima")
registrar_usuario("Luis", 22, "Quito")

assert len(usuarios) == 2
assert usuarios[0]["nombre"] == "Ana"

# %% [markdown]
# ## Paso 2: Mostrar usuarios
#
# Crea una función `listar_usuarios` que devuelva una lista con los nombres de los usuarios.

# %%
# TU CÓDIGO AQUÍ

def listar_usuarios():
    nombres = []
    for usuario in usuarios:
        nombres.append(usuario["nombre"])
    return nombres

# Pruebas simples
assert listar_usuarios() == ["Ana", "Luis"]

# %% [markdown]
# ## Paso 3: Buscar usuario
#
# Crea una función `buscar_usuario(nombre)` que devuelva el diccionario del usuario
# si existe o `None` si no está.

# %%
# TU CÓDIGO AQUÍ

def buscar_usuario(nombre):
    for usuario in usuarios:
        if usuario["nombre"].lower() == nombre.lower():
            return usuario
    return None

# Pruebas simples
assert buscar_usuario("Ana")["ciudad"] == "Lima"
assert buscar_usuario("NoExiste") is None

# %% [markdown]
# ## Paso 4: Eliminar usuario
#
# Crea una función `eliminar_usuario(nombre)` que elimine al usuario por nombre.
# Debe devolver `True` si eliminó algo o `False` si no encontró el usuario.

# %%
# TU CÓDIGO AQUÍ

def eliminar_usuario(nombre):
    indice = 0
    while indice < len(usuarios):
        if usuarios[indice]["nombre"].lower() == nombre.lower():
            usuarios.pop(indice)
            return True
        indice += 1
    return False

# Pruebas simples
assert eliminar_usuario("Luis") is True
assert eliminar_usuario("Luis") is False

# %% [markdown]
# ## Paso 5 (opcional): Menú en consola
#
# Si quieres llevar el proyecto a la consola, crea una función `menu()`
# que muestre opciones y use `input()` para interactuar.
# Este paso es opcional y no tiene pruebas automáticas.

# %%
# TU CÓDIGO AQUÍ (opcional)
# def menu():
#     ...

# %% [markdown]
# ## Retos opcionales
#
# - Agregar validaciones de entrada (por ejemplo, edad numérica).
# - Exportar usuarios a JSON.
# - Agregar contraseñas (solo strings).
# - Organizar el menú en subfunciones.

# %% [markdown]
# ### Nota pedagógica especial para el proyecto final
#
# Este proyecto no necesita ser perfecto: su objetivo es integrar lo que ya aprendiste.
# Puedes avanzar por partes y mejorar con el tiempo.
# Lo importante es que funcione lo básico y entiendas cómo cada pieza se conecta con lo aprendido en el curso.
